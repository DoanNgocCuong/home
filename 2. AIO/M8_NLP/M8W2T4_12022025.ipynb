# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Model Fast Response của mình đang có 1 số intent kiểu ...
# - Hỗ trợ chatbot: trong Detect Intent => Fast Response, ... [Mapping Intent với Fast Response] - Open Moxie: https://github.com/jbeghtol/openmoxie

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# - Vector Dense vector: đại diện cho ngữ nghĩ, các khía cạnh khác nhau của 1 từ. N từ => N vector, mỗi vector D chiều

# %% [markdown]
# XLM-RoBERTa: khuyến khích dùng: do tham số nhỏ gần BERT, mà performance ngon. Đúng bài mình làm cho công ty

# %% [markdown]
# Gọi là train BERT.
# - Pretraining BERT. Mô hình Pretraining là mô hình đầu tiên khi mình training.
# - Khi xong các version, tiếp tục tối ưu cho downtask => gọi là finetuning. Giờ thường cập nhật hết trọng số của model.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tại sao labels lại padding -100 không. Padding của labels = -100
