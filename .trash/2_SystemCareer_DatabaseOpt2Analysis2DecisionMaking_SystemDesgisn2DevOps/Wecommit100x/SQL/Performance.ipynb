# %% [markdown]
# 1. Chậm thì dễ.
# 2. Khổ cái là: bình thường nó nhanh, xong nó THI THOẢNG NÓ CHẬM => Hiệu năng không đồng đều (Kiểu percentile 95, 99 cao bất thường )
# ---
# 1. Độ phân bổ dữ liệu của bảng ko đồng đều
# 2. Chỉ có 1 plan
# 3. Có nhiều plan, nhưng nó cache plan cũ

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Còn gì nữa không

# %% [markdown]
# 4. Thay vì tạo Plan từng đầu. (Thay vì Estimate từ đầu để tạo Plan, thay vì A join B xài Nested Loop => Hãy để cho A run xong => Mới quyết định cách join với B)

# %% [markdown]
# ![image.png](attachment:image.png)
