# %% [markdown]
# - Khi docker compose build nó sẽ tìm đến các mục có chữ `build` vào build. Như trước chỉ để là image thì nó ko build.
# - Khi đặt là build nó sẽ build.
# - Khi chỉnh sửa các phần ko nằm ở mục build chẳng hạn :
# ```
#     volumes:
#       - ./volumes/app/web:/app/web  # Mount thư mục web vào container
#       # Hoặc có thể chi tiết hơn:
#       # - ./volumes/app/web/public:/app/web/public  # Mount thư mục public
#       # - ./volumes/app/web/storage:/app/web/storage  # Mount thư mục storage
#       # - ./volumes/app/web/uploads:/app/web/uploads  # Mount thư mục uploads nếu cần
# ```
# thì chỉ cần docker up
#
#
# ```
# yMTgyNDA3LCJpc3MiOiJTRUxGX0hPU1RFRCIsInN1YiI6IkNvbnNvbGUgQVBJIFBhc3Nwb3J0In0.JIaCEJ8ZEAqfktxnxLCYifgKkQ8cEFKnjTYG2B1dPuc HTTP/1.1" 502 559 "http://localhost/app/de207817-3603-4a46-8d5a-dd1c4d22830e/workflow" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36 Edg/132.0.0.0" "-"
# sandbox-1     | 2024/11/21 08:49:41 env.go:30: [WARN]python lib path /usr/lib/python3.10 is not available
# sandbox-1     | 2024/11/21 08:49:41 env.go:30: [WARN]python lib path /usr/lib/python3 is not available
# sandbox-1     | [GIN] 2024/11/21 - 08:49:43 | 404 |         700ns |              :: | GET      "/squid-internal-dynamic/netdb"
# nginx-1       | 2024/11/21 08:49:43 [error] 20#20: *1 connect() failed (113: No route to host) while connecting to upstream, client: 172.19.0.1, server: _, request: "GET /favicon.ico HTTP/1.1", upstream: "http://172.19.0.6:3000/favicon.ico", host: "localhost", referrer: "http://localhost/app/de207817-3603-4a46-8d5a-dd1c4d22830e/workflow"
# nginx-1       | 172.19.0.1 - - [21/Nov/2024:08:49:43 +0000] "GET /favicon.ico HTTP/1.1" 502 559 "http://localhost/app/de207817-3603-4a46-8d5a-dd1c4d22830e/workflow" "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/132.0.0.0 Safari/537.36 Edg/132.0.0.0" "-"
# api-1         | sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# api-1         | sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# worker-1      | sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# worker-1      | sagemaker.config INFO - Not applying SDK defaults from location: /root/.config/sagemaker/config.yaml
# sandbox-1     | [GIN] 2024/11/21 - 08:49:44 | 200 |     132.808µs |             ::1 | GET      "/health"
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# sandbox-1     | 2024/11/21 08:49:55 env.go:30: [WARN]python lib path /run/systemd/resolve/stub-resolv.conf is not available
# sandbox-1     | 2024/11/21 08:49:55 env.go:30: [WARN]python lib path /run/resolvconf/resolv.conf is not available
# sandbox-1     | 2024/11/21 08:50:03 server.go:60: [INFO]python dependencies sandbox initialized
# worker-1      | Preparing database migration...
# worker-1      | Starting database migration.
# api-1         | Preparing database migration...
# api-1         | Database migration skipped
# worker-1      | INFO  [alembic.runtime.migration] Context impl PostgresqlImpl.
# worker-1      | INFO  [alembic.runtime.migration] Will assume transactional DDL.
# worker-1      | Database migration successful!
# api-1         | None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# worker-1      | None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# web-1         | /bin/sh: can't open './entrypoint.sh': No such file or directory
# sandbox-1     | [GIN] 2024/11/21 - 08:50:14 | 200 |      27.901µs |             ::1 | GET      "/health"
# api-1         | sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
