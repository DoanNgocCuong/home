# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Cho 1 câu có độ dài = 4 từ. 2 từ đầu tạo ngữ cảnh, cần phân loại 2 từ sau. Phân loại 2 từ sau vào hộp nào trong 8 hộp

# %% [markdown]
# (N, L, C): (batch-size, seq-len, channel: embedding size)

# %% [markdown]
# ![image.png](attachment:image.png)
