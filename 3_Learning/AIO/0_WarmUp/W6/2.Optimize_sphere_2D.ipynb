# %%
# sphere function
def func(x, y):
    return x**2 + y**2

# gradient
def gradient(x, y):
    dx = 2*x
    dy = 2*y
    return dx, dy

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.colors import LogNorm

xmin, xmax, xstep = -4.5, 4.5, .2
ymin, ymax, ystep = -4.5, 4.5, .2 

x, y = np.meshgrid(np.arange(xmin, xmax + xstep, xstep), np.arange(ymin, ymax + ystep, ystep))
z = func(x, y)

# 3D Surface Plot
fig = plt.figure(figsize=(8, 5))
ax = plt.axes(projection='3d', elev=0, azim=-40)

ax.plot_surface(x, y, z, norm=LogNorm(), rstride=1, cstride=1, 
                edgecolor='none', alpha=.9, cmap=plt.cm.jet)

ax.set_xlabel('$x$')
ax.set_ylabel('$y$')
ax.set_zlabel('$z$')

ax.set_xlim((xmin, xmax))
ax.set_ylim((ymin, ymax))

plt.show()

# %%
import random

# set (x,y) randomly
x = random.randint(-100, 100)
y = random.randint(-100, 100)
print(x, y)

# params
num_iterations = 10
step = 1
lr = 0.1

# optimize
for _ in range(num_iterations):
    # compute the derivative at (x,y)
    dx, dy = gradient(x, y)
            
    # update
    x = x - lr*step
    y = y - lr*step
    
    print(x, y, func(x,y))
# Out:
# 28 4
# 27.9 3.9 793.62
# 27.799999999999997 3.8 787.2799999999999
# 27.699999999999996 3.6999999999999997 780.9799999999998
# 27.599999999999994 3.5999999999999996 774.7199999999997
# 27.499999999999993 3.4999999999999996 768.4999999999997
# 27.39999999999999 3.3999999999999995 762.3199999999995
# 27.29999999999999 3.2999999999999994 756.1799999999995
# 27.19999999999999 3.1999999999999993 750.0799999999994
# 27.099999999999987 3.099999999999999 744.0199999999993
# 26.999999999999986 2.999999999999999 737.9999999999992
