# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Từ có ->có làm hay có ăn ???? - Chọn sequence length = câu dài nhất. Khi cho câu ngắn vào thì padding.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Sau này chúng ta làm cái bài cứ đưa câu vào => Nó ra các con số. tức là mình dùng cái tokenizer có sẵn

# %% [markdown]
# ad ơi, trước em nhớ bên AIO mình có TRANG WEB riêng cho phần học NLP, LLMs đúng không ạ.
# ---
#
# Em nhớ trước có lần ad đăng lên pages, em vào lại link đó thì ko còn được ad ạ.

# %% [markdown]
# ad ơi, nếu câu dài hơn sequence_length thì có trường hợp đó không ạ.

# %% [markdown]
# Text classification: Dài hơn => Cắt bớt. Nhưng trong text generation thì ta lường trước, ko có chuyện đó

# %% [markdown]
#  input <sos> có 2 target token khác nhau thì nó bt dự đoán cái nào
#
# Trần Quang Minh;;;; 9:26 PM
# them guide token a nha, ai học buổi thứ 3 thì bt nà:))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1 từ được tuownggggggg tác với toàn bộ các từ trongg d

# %% [markdown]
# - Trong cùng ngữ cảnh, giữa transformer encoder và decoder thì tham số = nhau

# %% [markdown]
# - Nếu tensor cuối là output của model và đưa trực tiếp vào hàm loss trong pytorch như hình dưới thì B.Có lỗi xảy ra ()
# - Trong pytorch tensor cuối khi đưa vào hàm loss nhớ permute để chuyển (N, 2, 3) (3 embedding size) chiều sâu nằm ở giữa nên phải chuyển thành N, 3, 2
#
#
# ad ơi, tại sao pytorch nó lại thiết kế embedding size ở giữa thế ạ.
# (Có nguyên do gì không ạ, sao Pytorch họ ko thiết kế going tensor và keras ạ)
#
# X(C, H, W) - (N, C, H, W) - ông Yarn Li cun chuyên về dữ liệu arh (người đứng sau CNN)
#
# - Cái C, H, W + Conv => N, C', H', W' => Hàm loss bên CNN chạy oke hết vì nó chỉ cần C nằm sau N.
#
# - Họ mở rộng cho text, N, L => N, L, E đưa qua RNN, CNN đều oke hết.
# Mà nó lại  ngược với

# %% [markdown]
# ![image.png](attachment:image.png)
