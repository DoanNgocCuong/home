# %%
# !pip install pandas
# !pip install pygwalker
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# ...
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# ...
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached arrow-1.3.0-py3-none-any.whl.metadata (7.5 kB)
# ...
#   Using cached backoff-2.2.1-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached monotonic-1.6-py2.py3-none-any.whl.metadata (1.5 kB)
# ...
#   Using cached types_python_dateutil-2.9.0.20241206-py3-none-any.whl.metadata (2.1 kB)
# ...
#   Using cached importlib_resources-6.5.2-py3-none-any.whl.metadata (3.9 kB)
# ...
#    ---------------------------------------- 0.0/4.5 MB ? eta -:--:--
#    ---- ----------------------------------- 0.5/4.5 MB 4.2 MB/s eta 0:00:01
#    ---------------------------------------  4.5/4.5 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 4.5/4.5 MB 12.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# ## Chạy độc lập trong .ipynb

# %%
import pandas as pd
import pygwalker as pyg

# Đọc dữ liệu
df = pd.read_csv('advertising.csv')

# Hiển thị giao diện PygWalker trong notebook
walker = pyg.walk(df)

# %% [markdown]
# ## Chạy độc lập
# ```python
# import pandas as pd
# import pygwalker as pyg
#
# # Đọc dữ liệu
# df = pd.read_csv('du_lieu_cua_ban.csv')
#
# # Khởi động máy chủ web độc lập
# pyg.serve(df, port=8081)
# ```
