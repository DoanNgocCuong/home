# %% [markdown]
# - api/Dockerfile, web/Dockerfile sử dụng file pull sẵn thì ko bị
#     - api/Dockerfile: tự build image, web/Dockerfile: pull image sẵn thì hiển thị Log in nhưng điền xong thì ko LOG IN ĐƯỢC.
#     - api/Dockerfile: pull image sẵn, web/Dockerfile: tự build image thì bị BUG.
# - Cả 2 cái cùng build thì bug.
#
# => ASSUMPTION: web/Dockerfile mình tự build bị bug. Nhưng phần này bug sao được khi code trên máy ko thay đổi => web/Dockerfile có vấn đề?

# %% [markdown]
# ```
# vào trong thư mục web này set cho anh dòng 66, 67 như này rồi build image lại là được nha
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# web/app/signin/normalForm.tsx
