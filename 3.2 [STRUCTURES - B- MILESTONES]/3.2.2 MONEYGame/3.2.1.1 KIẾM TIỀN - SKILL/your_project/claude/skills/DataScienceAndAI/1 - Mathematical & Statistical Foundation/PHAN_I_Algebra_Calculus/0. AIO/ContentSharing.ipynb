# %% [markdown]
# Streak 5: [OPTIMIZATION PERSPECTIVE] - 5 Solutions for the Same Problem, but with Drastically Different Performance? 🚀
#
# hashtag#wecommit100x hashtag#wecommit100xhabit hashtag#python hashtag#ai
# ![image.png](attachment:image.png)

# %% [markdown]
# ```
# [GÓC ÔN TẬP W2]: Comprehension.
#
# Xin phép các ad, các TA.
# Em có summary lại về phần Comprehension, chia sẻ cho các ac, các bạn cùng học. Cảm ơn cả nhà ạ.
# Có gì chưa chính xác mọi người cứ feedback ạ. Chúc cả team học tập tốt ạ!! ^^
# #comprehension_python
# ```
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Học 4 năm rồi mới đúc kết được cái này (với sự support của AI)
